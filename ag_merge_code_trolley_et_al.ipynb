# %% [markdown]
# ##### Code for Trolley et al. CDOM merge paper
#
# Goal of this notebook:
# - construct dataframe of paired cary-100/ultrapath cdom measurements from provides seabass files
# - compute different merges for the paired measurements
# - reproduce all plots in the manuscript

# %%
import pandas as pd
import numpy as np

import sys
sys.path.append(r'C:\Users\gtrolley\Desktop\local_python\modules')
from SB_support import *    # the sb_support module can be retrieved from https://seabass.gsfc.nasa.gov/wiki/readsb_python 

import matplotlib.pyplot as plt
import datetime as dt
import scipy
import os
import matplotlib.pyplot as plt
import glob
import matplotlib as mpl
from cycler import cycler
import math
from pylab import *
import scipy as sp  
from scipy.interpolate import CubicSpline
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import re

# %% [markdown]
# Cruises in this study and link to cruise data on seabass:
#
# - CV3: https://seabass.gsfc.nasa.gov/cruise/cv3
# - CV4: https://seabass.gsfc.nasa.gov/cruise/cv4
# - CV5: https://seabass.gsfc.nasa.gov/cruise/cv5
# - CV6: https://seabass.gsfc.nasa.gov/cruise/cv6
# - CV7: https://seabass.gsfc.nasa.gov/cruise/cv7
# - P16S: https://seabass.gsfc.nasa.gov/cruise/p16s_2014
# - KORUS: https://seabass.gsfc.nasa.gov/cruise/kr_2016
# - NBS: https://seabass.gsfc.nasa.gov/cruise/Northern_Bering_Sea_2022
# - ECOA3: https://seabass.gsfc.nasa.gov/cruise/ECOA-3
#
# Data can either be manually downloaded from links above (tedious, need to sort cdom vs non-cdom data), or all relevant files can be downloaded from seabass using the cells below:
#
# I've also provided a 3rd option, which is to skip downloading seabass files, and use the pre-paired (by me)
# data stored in cary_ultrapath_paired_measurements.pkl as a starting point. if you do this, you can skip the cells
# up until the call for df = pd.read_pickle('cary_ultrapath_paired_measurements.pkl')
#
# ### Begin SeaBASS file download seciton - only need to run this section once

# %%
#function to retrieve downlaod links for cary and ultrapath_waveguide data
def get_filtered_download_links(url, required_substring=None):
    # Send GET request
    response = requests.get(url)
    response.raise_for_status()
    
    # Parse HTML
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Get all links first
    all_links = []
    
    # Method 1: Find links with download attribute
    for link in soup.find_all('a', href=True):
        if link.get('download'):
            full_url = urljoin(url, link['href'])
            all_links.append(full_url)
    
    # Method 2: Find links to common file types
    file_extensions = ['.pdf', '.zip', '.exe', '.dmg', '.deb', '.rpm', 
                      '.tar.gz', '.rar', '.7z', '.docx', '.xlsx', '.pptx']
    
    for link in soup.find_all('a', href=True):
        href = link['href']
        if any(href.lower().endswith(ext) for ext in file_extensions):
            full_url = urljoin(url, href)
            all_links.append(full_url)
    
    # Remove duplicates
    all_links = list(set(all_links))
    
    # Step 1: Filter to only keep links containing "/getfile/"
    getfile_links = [link for link in all_links if "/getfile/" in link]
    
    # Step 2: Split into waveguide and non-waveguide lists
    waveguide_links = [link for link in getfile_links if "waveguide" in link.lower()]
    potential_non_waveguide_links = [link for link in getfile_links if "waveguide" not in link.lower()]
    
    # Step 3: Filter non-waveguide links by additional substring if provided
    if required_substring:
        non_waveguide_links = [link for link in potential_non_waveguide_links 
                              if required_substring.lower() in link.lower()]
    else:
        non_waveguide_links = potential_non_waveguide_links
    
    return waveguide_links, non_waveguide_links

# # Example usage
# url = 'https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV3/archive'

# # Without additional filter
# waveguide_links, other_links = get_filtered_download_links(url)

# # With additional filter 
# waveguide_links, filtered_other_links = get_filtered_download_links(url, required_substring="")

# print("Waveguide links:")
# for link in waveguide_links:
#     print(f"  {link}")

# print(f"\nFiltered other links (containing 'antenna'):")
# for link in filtered_other_links:
#     print(f"  {link}")

# print(f"\nSummary:")
# print(f"  Waveguide links: {len(waveguide_links)}")
# print(f"  Filtered other links: {len(filtered_other_links)}")

# %%
# list of links along with substring that appears in all cary files for that cruise
data_source_links = [['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV3/archive','ag'],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV4/archive/ag',''],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV5/archive/ag',''],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV6/archive/ag',''],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV7/archive/ag',''],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVAR/p16s_2014/archive','cary100'],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/KORUS/KR_2016/archive','ag'],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/ARCTICCC/Northern_Bering_Sea_2022/archive', 'ag'],
                     ['https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/ECOA/ecoa-3/archive', 'ag']
                     ]

# %%
# loop to build list of download links for full dataset
wg_all = []
cary_all = []
for i in data_source_links:
    print(i[0])
    waveguide_links, cary_links = get_filtered_download_links(i[0], required_substring=i[1])
    wg_all.extend(waveguide_links)
    cary_all.extend(cary_links)

print('cary files:' + str(len(cary_all)))
print('ultrapath waveguide files:' + str(len(wg_all)))
# Out:
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV3/archive
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV4/archive/ag
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV5/archive/ag
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV6/archive/ag
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVEC/CV7/archive/ag
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/CLIVAR/p16s_2014/archive
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/KORUS/KR_2016/archive
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/ARCTICCC/Northern_Bering_Sea_2022/archive
# https://seabass.gsfc.nasa.gov/archive/NASA_GSFC/ECOA/ecoa-3/archive
# cary files:1172
# ultrapath waveguide files:1001

# %%
# next, make cary and ultrapath directories, download all files to each, and then remove hashes at beginning

cary_dir = 'cary_files/'
ultra_dir = 'ultrapath_files/'

os.makedirs(cary_dir, exist_ok=True) # if the folder doesnt exist yet, make it
os.makedirs(ultra_dir, exist_ok=True)

# %%
# this cell takes ~ 8 min
def extract_text_v2(s):# quick function to get filename from download link
    parts = s.split('/')[-1].split('_', 1)
    return parts[1] if len(parts) > 1 else ""

for url in cary_all:

    filename = extract_text_v2(url)
    savepath = cary_dir     
        
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raises an HTTPError for bad responses
        
        with open(savepath+'/'+filename, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        
        print(f"Downloaded: {filename}")
        #print(hycom_flist)
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        #return None
# Out:
# Downloaded: CV3_ag_st25A_00m.sb
# Downloaded: CV3_ag_st93_4.63m.sb
# Downloaded: CV3_ag_st26_5.63m.sb
# Downloaded: CV3_ag_st67A_00m.sb
# Downloaded: CV3_ag_st75_165.13m.sb
# Downloaded: CV3_ag_st93_44.13m.sb
# Downloaded: CV3_ag_st43_67.13m.sb
# Downloaded: CV3_ag_st39_00m.sb
# Downloaded: CV3_ag_st40_72.53m.sb
# Downloaded: CV3_ag_st94_00m.sb
# Downloaded: CV3_ag_st30A_00m.sb
# Downloaded: CV3_ag_st11_29.13m.sb
# Downloaded: CV3_ag_st17_134.13m.sb
# Downloaded: CV3_ag_st09_2.63m.sb
# Downloaded: CV3_ag_st11_2.13m.sb
# Downloaded: CV3_ag_st16A_00m.sb
# Downloaded: CV3_ag_st48_28.83m.sb
# Downloaded: CV3_ag_st58_51.53m.sb
# Downloaded: CV3_ag_st30_30.73m.sb
# Downloaded: CV3_ag_st15_2.63m.sb
# Downloaded: CV3_ag_st53_2.53m.sb
# Downloaded: CV3_ag_st15_00m.sb
# Downloaded: CV3_ag_st07_1.63m.sb
# Downloaded: CV3_ag_st58_00m.sb
# Downloaded: CV3_ag_st91_00m.sb
# Downloaded: CV3_ag_st68_00m.sb
# Downloaded: CV3_ag_st51_00m.sb
# Downloaded: CV3_ag_st25_2.23m.sb
# Downloaded: CV3_ag_st01_8.83m.sb
# Downloaded: CV3_ag_st26_14.03m.sb
# Downloaded: CV3_ag_st48_1.33m.sb
# Downloaded: CV3_ag_st07_69.13m.sb
# Downloaded: CV3_ag_st79_00m.sb
# Downloaded: CV3_ag_st30_1.93m.sb
# Downloaded: CV3_ag_st58_1.93m.sb
# Downloaded: CV3_ag_st01_1.83m.sb
# Downloaded: CV3_ag_st62_00m.sb
# Downloaded: CV3_ag_st59_00m.sb
# Downloaded: CV3_ag_st34_38.23m.sb
# Downloaded: CV3_ag_st31_1.83m.sb
# Downloaded: CV3_ag_st75_58.93m.sb
# Downloaded: CV3_ag_st42_00m.sb
# Downloaded: CV3_ag_st25_9.93m.sb
# Downloaded: CV3_ag_st89_36.63m.sb
# Downloaded: CV3_ag_st76_00m.sb
# Downloaded: CV3_ag_st52_00m.sb
# Downloaded: CV3_ag_st77_248.13m.sb
# Downloaded: CV3_ag_st60_00m.sb
# Downloaded: CV3_ag_st14A_00m.sb
# Downloaded: CV3_ag_st39A_00m.sb
# Downloaded: CV3_ag_st58_425.63m.sb
# Downloaded: CV3_ag_st15_49.43m.sb
# Downloaded: CV3_ag_st40_2.43m.sb
# Downloaded: CV3_ag_st34_2.43m.sb
# Downloaded: CV3_ag_st32_00m.sb
# Downloaded: CV3_ag_st81_00m.sb
# Downloaded: CV3_ag_st31_19.33m.sb
# Downloaded: CV3_ag_st17_2.63m.sb
# Downloaded: CV3_ag_st61_00m.sb
# Downloaded: CV3_ag_st77_2.43m.sb
# Downloaded: CV3_ag_st94_2.33m.sb
# Downloaded: CV3_ag_st49_308.13m.sb
# Downloaded: CV3_ag_st89_2.53m.sb
# Downloaded: CV3_ag_st94_47.33m.sb
# Downloaded: CV3_ag_st09_89.63m.sb
# Downloaded: CV3_ag_st49_00m.sb
# Downloaded: CV3_ag_st43_3.83m.sb
# Downloaded: CV3_ag_st14B_00m.sb
# Downloaded: CV3_ag_st53_69.73m.sb
# Downloaded: CV3_ag_st50_54.63m.sb
# Downloaded: CV3_ag_st77_61.53m.sb
# Downloaded: CV3_ag_st33_00m.sb
# Downloaded: CV3_ag_st50_2.63m.sb
# Downloaded: CV4_ag_st42_13.2m.sb
# Downloaded: CV4_ag_st45_17.8m.sb
# Downloaded: CV4_ag_st101_26.1m.sb
# Downloaded: CV4_ag_st126_245m.sb
# Downloaded: CV4_ag_st51C_00m.sb
# Downloaded: CV4_ag_st31_19.2m.sb
# Downloaded: CV4_ag_st89_16.8m.sb
# Downloaded: CV4_ag_st110_31.9m.sb
# Downloaded: CV4_ag_st93_00m.sb
# Downloaded: CV4_ag_st91_00m.sb
# Downloaded: CV4_ag_st62_31.9m.sb
# Downloaded: CV4_ag_st11_32m.sb
# Downloaded: CV4_ag_st126_34.8m.sb
# Downloaded: CV4_ag_st53_12.1m.sb
# Downloaded: CV4_ag_st71_3.8m.sb
# Downloaded: CV4_ag_st51_10.3m.sb
# Downloaded: CV4_ag_st32A_00m.sb
# Downloaded: CV4_ag_st119_18.1m.sb
# Downloaded: CV4_ag_st20_29.4m.sb
# Downloaded: CV4_ag_st39_20.7m.sb
# Downloaded: CV4_ag_st69A_00m.sb
# Downloaded: CV4_ag_st66A_00m.sb
# Downloaded: CV4_ag_st53_2.5m.sb
# Downloaded: CV4_ag_st60A_00m.sb
# Downloaded: CV4_ag_st30A_00m.sb
# Downloaded: CV4_ag_st53_21.6m.sb
# Downloaded: CV4_ag_st129_00m.sb
# Downloaded: CV4_ag_st51_2.8m.sb
# Downloaded: CV4_ag_st71_22.6m.sb
# Downloaded: CV4_ag_st51A_00m.sb
# Downloaded: CV4_ag_st60_3.2m.sb
# Downloaded: CV4_ag_st11_3.1m.sb
# Downloaded: CV4_ag_st60_31.7m.sb
# Downloaded: CV4_ag_st127_30.1m.sb
# Downloaded: CV4_ag_st92_11.2m.sb
# Downloaded: CV4_ag_st143_19.5m.sb
# Downloaded: CV4_ag_st46_00m.sb
# Downloaded: CV4_ag_st43A_00m.sb
# Downloaded: CV4_ag_st51_22.1m.sb
# Downloaded: CV4_ag_st8_3m.sb
# Downloaded: CV4_ag_st11_26.8m.sb
# Downloaded: CV4_ag_st94_18.2m.sb
# Downloaded: CV4_ag_st87_222m.sb
# Downloaded: CV4_ag_st30_18.7m.sb
# Downloaded: CV4_ag_st83_44.3m.sb
# Downloaded: CV4_ag_st31_2.6m.sb
# Downloaded: CV4_ag_st33_16.7m.sb
# Downloaded: CV4_ag_st89_20.1m.sb
# Downloaded: CV4_ag_st143_2.7m.sb
# Downloaded: CV4_ag_st122_3.3m.sb
# Downloaded: CV4_ag_st89_2.1m.sb
# Downloaded: CV4_ag_st105_27.2m.sb
# Downloaded: CV4_ag_st110_2.8m.sb
# Downloaded: CV4_ag_st69_00m.sb
# Downloaded: CV4_ag_st101_16.5m.sb
# Downloaded: CV4_ag_st30_24.5m.sb
# Downloaded: CV4_ag_st42_2.9m.sb
# Downloaded: CV4_ag_st30_3m.sb
# Downloaded: CV4_ag_st81_2.9m.sb
# Downloaded: CV4_ag_st141_00m.sb
# Downloaded: CV4_ag_st119_2.9m.sb
# Downloaded: CV4_ag_st126_2.7m.sb
# Downloaded: CV4_ag_st39_2.8m.sb
# Downloaded: CV4_ag_st81_10.7m.sb
# Downloaded: CV4_ag_st87_4m.sb
# Downloaded: CV4_ag_st81_50.6m.sb
# Downloaded: CV4_ag_st14_17m.sb
# Downloaded: CV4_ag_st77_8.5m.sb
# Downloaded: CV4_ag_st121_00m.sb
# Downloaded: CV4_ag_st92_3m.sb
# Downloaded: CV4_ag_st120_17.7m.sb
# Downloaded: CV4_ag_st83_20.5m.sb
# Downloaded: CV4_ag_st141_26.7m.sb
# Downloaded: CV4_ag_st41A_00m.sb
# Downloaded: CV4_ag_st122_34.3m.sb
# Downloaded: CV4_ag_st82_00m.sb
# Downloaded: CV4_ag_st8_26.4m.sb
# Downloaded: CV4_ag_st61_00m.sb
# Downloaded: CV4_ag_st101_2.9m.sb
# Downloaded: CV4_ag_st1_34m.sb
# Downloaded: CV4_ag_st104A_00m.sb
# Downloaded: CV4_ag_st136_26.1m.sb
# Downloaded: CV4_ag_st128_35.4m.sb
# Downloaded: CV4_ag_st127_20.3m.sb
# Downloaded: CV4_ag_st41_00m.sb
# Downloaded: CV4_ag_st104_25.7m.sb
# Downloaded: CV4_ag_st77_00m.sb
# Downloaded: CV4_ag_st129B_00m.sb
# Downloaded: CV4_ag_st109_2.9m.sb
# Downloaded: CV4_ag_st130_2.8m.sb
# Downloaded: CV4_ag_st105_3.3m.sb
# Downloaded: CV4_ag_st118A_00m.sb
# Downloaded: CV4_ag_st141_2.7m.sb
# Downloaded: CV4_ag_st31_9.2m.sb
# Downloaded: CV4_ag_st20_2.7m.sb
# Downloaded: CV4_ag_st114_00m.sb
# Downloaded: CV4_ag_st126_15m.sb
# Downloaded: CV4_ag_st77_29.3m.sb
# Downloaded: CV4_ag_st109_45.2m.sb
# Downloaded: CV4_ag_st139A_00m.sb
# Downloaded: CV4_ag_st109A_00m.sb
# Downloaded: CV4_ag_st41B_00m.sb
# Downloaded: CV4_ag_st23_2.8m.sb
# Downloaded: CV4_ag_st103_00m.sb
# Downloaded: CV4_ag_st109_150.1m.sb
# Downloaded: CV4_ag_st127_3.3m.sb
# Downloaded: CV4_ag_st92_20.5m.sb
# Downloaded: CV4_ag_st3_21.6m.sb
# Downloaded: CV4_ag_st130_20.8m.sb
# Downloaded: CV4_ag_st101_00m.sb
# Downloaded: CV4_ag_st132_00m.sb
# Downloaded: CV4_ag_st14_3.3m.sb
# Downloaded: CV4_ag_st62_27.5m.sb
# Downloaded: CV4_ag_st59A_00m.sb
# Downloaded: CV4_ag_st31_00m.sb
# Downloaded: CV4_ag_st33_2.9m.sb
# Downloaded: CV4_ag_st94_2.8m.sb
# Downloaded: CV4_ag_st33_21.8m.sb
# Downloaded: CV4_ag_st51B_00m.sb
# Downloaded: CV4_ag_st60_18.5m.sb
# Downloaded: CV4_ag_st39_10.6m.sb
# Downloaded: CV4_ag_st83_4m.sb
# Downloaded: CV4_ag_st112_00m.sb
# Downloaded: CV4_ag_st20_13.3m.sb
# Downloaded: CV4_ag_st50A_00m.sb
# Downloaded: CV4_ag_st94_25.1m.sb
# Downloaded: CV4_ag_st110_00m.sb
# Downloaded: CV4_ag_st43_00m.sb
# Downloaded: CV4_ag_st119_45.7m.sb
# Downloaded: CV4_ag_st120_22.4m.sb
# Downloaded: CV4_ag_st1_11.9m.sb
# Downloaded: CV4_ag_st48_2.4m.sb
# Downloaded: CV4_ag_st104_9.4m.sb
# Downloaded: CV4_ag_st3_7.3m.sb
# Downloaded: CV4_ag_st77_2.3m.sb
# Downloaded: CV4_ag_st58_21.8m.sb
# Downloaded: CV4_ag_st130_13.5m.sb
# Downloaded: CV4_ag_st128_3.4m.sb
# Downloaded: CV4_ag_st23_20.2m.sb
# Downloaded: CV4_ag_st143_12.2m.sb
# Downloaded: CV4_ag_st32_00m.sb
# Downloaded: CV4_ag_st3_2.8m.sb
# Downloaded: CV4_ag_st120_2.8m.sb
# Downloaded: CV4_ag_st1_2m.sb
# Downloaded: CV4_ag_st141_14m.sb
# Downloaded: CV4_ag_st136_1.8m.sb
# Downloaded: CV4_ag_st45_2.7m.sb
# Downloaded: CV4_ag_st62_4.5m.sb
# Downloaded: CV4_ag_st71_35.1m.sb
# Downloaded: CV4_ag_st128_13.1m.sb
# Downloaded: CV4_ag_st48_25.5m.sb
# Downloaded: CV4_ag_st24_22.3m.sb
# Downloaded: CV4_ag_st22_325m.sb
# Downloaded: CV4_ag_st109_23.4m.sb
# Downloaded: CV4_ag_st104_2.7m.sb
# Downloaded: CV4_ag_st129A_00m.sb
# Downloaded: CV4_ag_st136_19.2m.sb
# Downloaded: CV4_ag_st80_00m.sb
# Downloaded: CV4_ag_st42_15.3m.sb
# Downloaded: CV4_ag_st105_20.6m.sb
# Downloaded: CV4_ag_st8_8m.sb
# Downloaded: CV4_ag_st122_20.1m.sb
# Downloaded: CV4_ag_st24_11.6m.sb
# Downloaded: CV4_ag_st45_10m.sb
# Downloaded: CV4_ag_st58_2.4m.sb
# Downloaded: CV4_ag_st23_28.5m.sb
# Downloaded: CV4_ag_st14_25.2m.sb
# Downloaded: CV4_ag_st121A_00m.sb
# Downloaded: CV4_ag_st24_3.3m.sb
# Downloaded: CV4_ag_st48_14.3m.sb
# Downloaded: CV5_ag_st74_2.93m.sb
# Downloaded: CV5_ag_st7_2.33m.sb
# Downloaded: CV5_ag_st96_1.23m.sb
# Downloaded: CV5_ag_st71_92.13m.sb
# Downloaded: CV5_ag_st97_2.63m.sb
# Downloaded: CV5_ag_st35_7.23m.sb
# Downloaded: CV5_ag_st131A_00m.sb
# Downloaded: CV5_ag_st39_00m.sb
# Downloaded: CV5_ag_st132_2.53m.sb
# Downloaded: CV5_ag_st103_00m.sb
# Downloaded: CV5_ag_st130_31.43m.sb
# Downloaded: CV5_ag_st121_11.23m.sb
# Downloaded: CV5_ag_st97_290.13m.sb
# Downloaded: CV5_ag_st97_38.43m.sb
# Downloaded: CV5_ag_st108_00m.sb
# Downloaded: CV5_ag_st118A_00m.sb
# Downloaded: CV5_ag_st133_2.93m.sb
# Downloaded: CV5_ag_st85_15.23m.sb
# Downloaded: CV5_ag_st18A_00m.sb
# Downloaded: CV5_ag_st71_19.63m.sb
# Downloaded: CV5_ag_st97_15.03m.sb
# Downloaded: CV5_ag_st117_00m.sb
# Downloaded: CV5_ag_st55_00m.sb
# Downloaded: CV5_ag_st87_34.73m.sb
# Downloaded: CV5_ag_st54A_00m.sb
# Downloaded: CV5_ag_st74_14.43m.sb
# Downloaded: CV5_ag_st53B_00m.sb
# Downloaded: CV5_ag_st37_00m.sb
# Downloaded: CV5_ag_st35_1.63m.sb
# Downloaded: CV5_ag_st9_2.03m.sb
# Downloaded: CV5_ag_st109_16.43m.sb
# Downloaded: CV5_ag_st107_00m.sb
# Downloaded: CV5_ag_st65_11.53m.sb
# Downloaded: CV5_ag_st48A_00m.sb
# Downloaded: CV5_ag_st71_551.13m.sb
# Downloaded: CV5_ag_st130_2.53m.sb
# Downloaded: CV5_ag_st10_20.43m.sb
# Downloaded: CV5_ag_st132_00m.sb
# Downloaded: CV5_ag_st28_00m.sb
# Downloaded: CV5_ag_st71_2.33m.sb
# Downloaded: CV5_ag_st96_21.53m.sb
# Downloaded: CV5_ag_st109_147.63m.sb
# Downloaded: CV5_ag_st10_2.33m.sb
# Downloaded: CV5_ag_st132_124.13m.sb
# Downloaded: CV5_ag_st87_2.33m.sb
# Downloaded: CV5_ag_st18_00m.sb
# Downloaded: CV5_ag_st85_30.93m.sb
# Downloaded: CV5_ag_st133_29.23m.sb
# Downloaded: CV5_ag_st26_00m.sb
# Downloaded: CV5_ag_st45A_00m.sb
# Downloaded: CV5_ag_st44A_00m.sb
# Downloaded: CV5_ag_st85_2.63m.sb
# Downloaded: CV5_ag_st20_00m.sb
# Downloaded: CV5_ag_st7A_00m.sb
# Downloaded: CV5_ag_st76_11.53m.sb
# Downloaded: CV5_ag_st10_7.33m.sb
# Downloaded: CV5_ag_st110_00m.sb
# Downloaded: CV5_ag_st121_2.43m.sb
# Downloaded: CV5_ag_st17_00m.sb
# Downloaded: CV5_ag_st109_2.43m.sb
# Downloaded: CV5_ag_st72_2.53m.sb
# Downloaded: CV5_ag_st109_44.93m.sb
# Downloaded: CV5_ag_st130_120m.sb
# Downloaded: CV5_ag_st28_9.13m.sb
# Downloaded: CV5_ag_st76_2.33m.sb
# Downloaded: CV5_ag_st96_50.33m.sb
# Downloaded: CV5_ag_st39_11.23m.sb
# Downloaded: CV5_ag_st119_00m.sb
# Downloaded: CV5_ag_st64_00m.sb
# Downloaded: CV5_ag_st88_40.13m.sb
# Downloaded: CV5_ag_st29A_00m.sb
# Downloaded: CV5_ag_st61A_00m.sb
# Downloaded: CV5_ag_st94_129.13m.sb
# Downloaded: CV5_ag_st102_00m.sb
# Downloaded: CV5_ag_st130_15.53m.sb
# Downloaded: CV5_ag_st88_2.63m.sb
# Downloaded: CV5_ag_st74_54.43m.sb
# Downloaded: CV5_ag_st94_14.33m.sb
# Downloaded: CV5_ag_st28_2.23m.sb
# Downloaded: CV5_ag_st71_47.13m.sb
# Downloaded: CV5_ag_st72_47.63m.sb
# Downloaded: CV5_ag_st96_199.53m.sb
# Downloaded: CV5_ag_st35A_00m.sb
# Downloaded: CV5_ag_st7_19.13m.sb
# Downloaded: CV5_ag_st117_149.53m.sb
# Downloaded: CV5_ag_st39_2.43m.sb
# Downloaded: CV5_ag_st121_00m.sb
# Downloaded: CV5_ag_st47_00m.sb
# Downloaded: CV5_ag_st73_00m.sb
# Downloaded: CV5_ag_st9_7.43m.sb
# Downloaded: CV5_ag_st63_00m.sb
# Downloaded: CV5_ag_st121_27.23m.sb
# Downloaded: CV5_ag_st109A_00m.sb
# Downloaded: CV5_ag_st53A_00m.sb
# Downloaded: CV5_ag_st44B_00m.sb
# Downloaded: CV5_ag_st87_10.83m.sb
# Downloaded: CV5_ag_st46_00m.sb
# Downloaded: CV5_ag_st54_00m.sb
# Downloaded: CV5_ag_st117_34.33m.sb
# Downloaded: CV5_ag_st33_1.63m.sb
# Downloaded: CV5_ag_st65_24.73m.sb
# Downloaded: CV5_ag_st76_47.43m.sb
# Downloaded: CV5_ag_st133_11.53m.sb
# Downloaded: CV5_ag_st7_9.73m.sb
# Downloaded: CV5_ag_st36_8.13m.sb
# Downloaded: CV5_ag_st117_14.53m.sb
# Downloaded: CV5_ag_st72_94.13m.sb
# Downloaded: CV5_ag_st52A_00m.sb
# Downloaded: CV5_ag_st27A_00m.sb
# Downloaded: CV5_ag_st65_2.63m.sb
# Downloaded: CV5_ag_st44_00m.sb
# Downloaded: CV5_ag_st88_11.63m.sb
# Downloaded: CV5_ag_st87_149.13m.sb
# Downloaded: CV5_ag_st45_00m.sb
# Downloaded: CV5_ag_st9_22.13m.sb
# Downloaded: CV5_ag_st94_1.63m.sb
# Downloaded: CV5_ag_st132_13.73m.sb
# Downloaded: CV5_ag_st117_2.43m.sb
# Downloaded: CV5_ag_st95_00m.sb
# Downloaded: CV5_ag_st17A_00m.sb
# Downloaded: CV5_ag_st36_1.63m.sb
# Downloaded: CV5_ag_st30_2.33m.sb
# Downloaded: CV5_ag_st88_00m.sb
# Downloaded: CV5_ag_st94_41.63m.sb
# Downloaded: CV5_ag_st38_00m.sb
# Downloaded: CV5_ag_st85_89.13m.sb
# Downloaded: CV5_ag_st72_14.33m.sb
# Downloaded: CV6_ag_st61_14.9m.sb
# Downloaded: CV6_ag_st64_2.5m.sb
# Downloaded: CV6_ag_st150_00m.sb
# Downloaded: CV6_ag_st98_57m.sb
# Downloaded: CV6_ag_st63_00m.sb
# Downloaded: CV6_ag_st155_2.5m.sb
# Downloaded: CV6_ag_st10_48m.sb
# Downloaded: CV6_ag_st22_63m.sb
# Downloaded: CV6_ag_st07_19m.sb
# Downloaded: CV6_ag_st07_3m.sb
# Downloaded: CV6_ag_st173_2.9m.sb
# Downloaded: CV6_ag_st56_22.4m.sb
# Downloaded: CV6_ag_st152_22.5m.sb
# Downloaded: CV6_ag_st110_16.1m.sb
# Downloaded: CV6_ag_st10_30m.sb
# Downloaded: CV6_ag_st102_3.1m.sb
# Downloaded: CV6_ag_st136_37.4m.sb
# Downloaded: CV6_ag_st91_2.8m.sb
# Downloaded: CV6_ag_st77_00m.sb
# Downloaded: CV6_ag_st91_29.7m.sb
# Downloaded: CV6_ag_st124_95m.sb
# Downloaded: CV6_ag_st147_30.2m.sb
# Downloaded: CV6_ag_st33_3.2m.sb
# Downloaded: CV6_ag_st176_11.5m.sb
.sb
# Downloaded: CLIVAR_p16s_cary100_ag_20140502_st83_135m.sb
# Downloaded: CLIVAR_p16s_cary100_ag_20140330_st3_160m.sb
# Downloaded: KORUS_ag_20160522_st4_20m.sb
# Downloaded: KORUS_ag_20160525_st30_30m.sb
# Downloaded: KORUS_ag_20160528_st50.1_40m.sb
# Downloaded: KORUS_ag_20160528_st48_20m.sb
# Downloaded: KORUS_ag_20160525_st31_2m.sb
# Downloaded: KORUS_ag_20160524_st29_2m.sb
# Downloaded: KORUS_ag_20160529_st51_2m.sb
# Downloaded: KORUS_ag_20160530_st60_2m.sb
# Downloaded: KORUS_ag_20160524_st25_75m.sb
# Downloaded: KORUS_ag_20160522_st2.3_0m.sb
# Downloaded: KORUS_ag_20160530_st65_2m.sb
# Downloaded: KORUS_ag_20160526_st40_24m.sb
# Downloaded: KORUS_ag_20160522_st4_0m.sb
# Downloaded: KORUS_ag_20160603_st84_24m.sb
# Downloaded: KORUS_ag_20160522_st12_40m.sb
# Downloaded: KORUS_ag_20160602_st79_25m.sb
# Downloaded: KORUS_ag_20160530_st59_0m.sb
# Downloaded: KORUS_ag_20160605_st88_40m.sb
# Downloaded: KORUS_ag_20160605_st88_4m.sb
# Downloaded: KORUS_ag_20160528_st46_0m.sb
# Downloaded: KORUS_ag_20160522_st10_60m.sb
# Downloaded: KORUS_ag_20160527_st43_2.8m.sb
# Downloaded: KORUS_ag_20160525_st33_43m.sb
# Downloaded: KORUS_ag_20160525_st37.1_60m.sb
# Downloaded: KORUS_ag_20160528_st49_52m.sb
# Downloaded: KORUS_ag_20160603_st82_40m.sb
# Downloaded: KORUS_ag_20160525_st34_35m.sb
# Downloaded: KORUS_ag_20160527_st43_20m.sb
# Downloaded: KORUS_ag_20160523_st18_30m.sb
# Downloaded: KORUS_ag_20160522_st9_2m.sb
# Downloaded: KORUS_ag_20160531_st67_2m.sb
# Downloaded: KORUS_ag_20160524_st29_44m.sb
# Downloaded: KORUS_ag_20160523_st21_26m.sb
# Downloaded: KORUS_ag_20160525_st33_2m.sb
# Downloaded: KORUS_ag_20160601_st69_0m.sb
# Downloaded: KORUS_ag_20160531_st66_20m.sb
# Downloaded: KORUS_ag_20160530_st63_32m.sb
# Downloaded: KORUS_ag_20160529_st53_17m.sb
# Downloaded: KORUS_ag_20160523_st19_2m.sb
# Downloaded: KORUS_ag_20160526_st41_2m.sb
# Downloaded: KORUS_ag_20160602_st77_40m.sb
# Downloaded: KORUS_ag_20160605_st88_30m.sb
# Downloaded: KORUS_ag_20160526_st38_40m.sb
# Downloaded: KORUS_ag_20160523_st18_60m.sb
# Downloaded: KORUS_ag_20160528_st46_40m.sb
# Downloaded: KORUS_ag_20160530_st62_30m.sb
# Downloaded: KORUS_ag_20160530_st61_2m.sb
# Downloaded: KORUS_ag_20160531_st67_21m.sb
# Downloaded: KORUS_ag_20160530_st62_50m.sb
# Downloaded: KORUS_ag_20160602_st77_30m.sb
# Downloaded: KORUS_ag_20160522_st3.1_2m.sb
# Downloaded: KORUS_ag_20160601_st68.1_0m.sb
# Downloaded: KORUS_ag_20160603_st83_3m.sb
# Downloaded: KORUS_ag_20160523_st22_2m.sb
# Downloaded: KORUS_ag_20160530_st59_30m.sb
0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st53_17m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st81_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st67_21m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st65_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st69_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st32_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st42_18m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st17_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st88_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st38_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st66_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st2.3_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st61_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st52_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st76_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st8_2.5m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st73_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st47_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st30_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st43_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st48_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st24_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st77_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st62_50m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st51_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st48_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st51_23m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st88_4m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st80_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st41_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st47_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st76_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st77_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st71_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st42_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st90_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st46_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st89.1_2.4m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st34_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st75_32m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st19_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st52_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st46_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st32_50m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st21_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st34_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st70_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st31_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st62_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st67_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st59_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st10_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st38_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st51_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st71_34m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st60_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st37.1_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st33_43m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st29_50m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st79_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st90_6m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st69_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st58_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st40_10m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st81_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st65_23m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st66_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st72_18m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st31_10m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st38_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st75_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st4_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st68_17m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st41_10m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st30_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st41_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st84_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st82_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st2.1_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st83_3m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st25_5m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st33_50m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st50.1_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st90_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st29_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st39_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st73_50m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st31_36m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st40_24m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st49_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st66_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st76_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st40_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st88_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st37.1_60m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st61_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st25_61m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st39_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st47_27m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st72_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st79_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st43_2.8m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st84_31m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st60_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st32_43m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st48_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st69_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st42_2.5m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st22_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st89.1_20m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st18_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st34_35m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st74_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st84_24m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st24_60m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st83_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st52_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st30_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st37.1_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st68_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st3.1_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st49_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160524_st29_44m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st65_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st75_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st49_52m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st23_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st40_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st70_34m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st41_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st53_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st54_34m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st9_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st62_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st82_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st59_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st46_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160531_st67_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_st89.1_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160525_st33_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st63_32m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160602_st79_25m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st80_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st12_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160522_st2.2_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st50.1_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st73_24m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st53_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160529_st54_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st45.1_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st45.1_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160523_st20_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st61_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st80_25m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160527_st45.1_30m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160528_st50.1_23m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160603_st81_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st60_40m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160601_st68.1_0m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160526_st39_2m_R1.sb
# Downloaded: KORUS_KR_2016_Ultrapath_waveguide_ag_20160530_st59_30m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220911_st26_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220915_st40_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220913_st33_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220915_st37_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220913_st32_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220912_st29_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220911_st27_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220912_st30_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220915_st39_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220911_st25_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220914_st35_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220914_st34_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220913_st31_2m_R1.sb
# Downloaded: ArcticCC_Northern_Bering_Sea_Ultrapath_waveguide_ag_20220915_st38_2m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220813_st31_28m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220920_st205_2m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220809_st5_12m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220821_st77b_28m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220912_st166_2m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220814_st33_4m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220811_st20_190m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220818_st58_22m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220920_st205_72m_R1.sb
# Downloaded: ECOA_ECOA_3_Ultrapath_waveguide_ag_20220821_st77a_5m_R1.sb

# %% [markdown]
# ### End Seabass File download section

# %% [markdown]
# ### Start section, assembling paired measurement table from individual files

# %%
def get_cary_fname(sb):
    # given an sb file, parse the comments and retrieve the corresponding cary file name
    comment_index = [i for i, s in enumerate(sb.comments) if 'paired_cary_ag_file:' in s]
    comment_line = sb.comments[comment_index[0]]
    cary_fname = comment_line[21:]
    return cary_fname

# %%
def trim_wavelength_data_concise(data, min_wavelength=250.0):
    # Find the index where wavelength >= min_wavelength
    start_index = next((i for i, w in enumerate(data['wavelength']) if w >= min_wavelength), None)
    
    if start_index is None:
        return OrderedDict([(k, []) for k in data.keys()])
    
    # Create a new OrderedDict with sliced data
    return OrderedDict([(k, v[start_index:]) for k, v in data.items()])

# %%
# this cell: begin analysis, assume all cary files were downloaded to cary folder, and all ultrapath files downloaded to ultrapath folder before running

# get list of files in both directories
cary_dir = 'cary_files/'
ultra_dir = 'ultrapath_files/'
cary_flist = os.listdir(cary_dir)
ultra_flist = os.listdir(ultra_dir)



crz_list=[]
ultradat_list=[]
carydat_list=[]
ultra_files_list = []
cary_files_list =[]

# basic strucute: iterate through ultrapath data. load the file and write relevant info to df. Extract the corresponding cary filename 
# (i've added these as a comment in the seabass header), then load that data to the df as well and save the info
for ultra_file in ultra_flist:
    ultra_sb = readSB(filename=ultra_dir+ultra_file, no_warn=True)
    cary_file = get_cary_fname(ultra_sb)
    cary_sb = readSB(filename=cary_dir+cary_file, no_warn=True)
    cary_data = cary_sb.data

    # ### logic to interpolate cary_data to integers, needed since some .sb files have non integer wavelengths
    # cary_data.set_index('wavelength')
    # cary_data.sort_index(inplace=True)
    # new_index = np.arange(int(cary_data.index.min()), int(cary_data.index.max()) + 1)
    # cary_data = cary_data.reindex(new_index, method='nearest')
    # cary_data.reset_index
    # cary_data = cary_data.to_dict('series', into=OrderedDict)
    # ###

    #ultra_data = trim_wavelength_data_concise(ultra_sb.data)
    ultra_data = ultra_sb.data

    crz = ultra_sb.headers['cruise']
    crz_list.append(crz)
    ultradat_list.append(ultra_data)
    carydat_list.append(cary_data)
    ultra_files_list.append(ultra_file)
    cary_files_list.append(cary_file)


df = pd.DataFrame(ultra_files_list, columns=['ultrapath_file'])
df['cary_file'] = cary_files_list
df['cruise']=crz_list
df['Ultrapath_data']=ultradat_list
df['Cary_data']=carydat_list

# at this point, df has paired measurements and includes the filename and data from the cary+ultrapath, plus the cruise name


df.to_pickle("cary_ultrapath_paired_measurements.pkl") # write paired cary ultrapath data to .pkl file. I provide this as well if you want to skip file downloads
df

# with pd.option_context('display.max_rows', None):
#     display(df['cary_file'])
# Out:
#                                          ultrapath_file  \
# 0     ArcticCC_Northern_Bering_Sea_Ultrapath_wavegui...
# 1     ArcticCC_Northern_Bering_Sea_Ultrapath_wavegui...
# 2     ArcticCC_Northern_Bering_Sea_Ultrapath_wavegui...
# 3     ArcticCC_Northern_Bering_Sea_Ultrapath_wavegui...
# 4     ArcticCC_Northern_Bering_Sea_Ultrapath_wavegui...
# ...                                                 ...
# 996   KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_...
# 997   KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_...
# 998   KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_...
# 999   KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_...
# 1000  KORUS_KR_2016_Ultrapath_waveguide_ag_20160605_...
#
#                                             cary_file  \
# 0     ArcticCC_Northern_Bering_Sea_2022_ag_st25_R2.sb
# 1     ArcticCC_Northern_Bering_Sea_2022_ag_st26_R2.sb
# 2     ArcticCC_Northern_Bering_Sea_2022_ag_st27_R2.sb
# 3     ArcticCC_Northern_Bering_Sea_2022_ag_st29_R2.sb
# 4     ArcticCC_Northern_Bering_Sea_2022_ag_st30_R2.sb
# ...                                               ...
# 996                  KORUS_ag_20160605_st89.1_2.4m.sb
# 997                   KORUS_ag_20160605_st89.1_20m.sb
# 998                     KORUS_ag_20160605_st90_30m.sb
# 999                     KORUS_ag_20160605_st90_40m.sb
# 1000                     KORUS_ag_20160605_st90_6m.sb
#
#                         cruise  \
# 0     Northern_Bering_Sea_2022
# 1     Northern_Bering_Sea_2022
# 2     Northern_Bering_Sea_2022
# 3     Northern_Bering_Sea_2022
# 4     Northern_Bering_Sea_2022
# ...                        ...
# 996                    KR_2016
# 997                    KR_2016
# 998                    KR_2016
# 999                    KR_2016
# 1000                   KR_2016
#
#                                          Ultrapath_data  \
# 0     {'wavelength': [186.0, 187.0, 188.0, 189.0, 19...
# 1     {'wavelength': [186.0, 187.0, 188.0, 189.0, 19...
# 2     {'wavelength': [186.0, 187.0, 188.0, 189.0, 19...
# 3     {'wavelength': [186.0, 187.0, 188.0, 189.0, 19...
# 4     {'wavelength': [186.0, 187.0, 188.0, 189.0, 19...
# ...                                                 ...
# 996   {'wavelength': [201.0, 202.0, 203.0, 204.0, 20...
# 997   {'wavelength': [201.0, 202.0, 203.0, 204.0, 20...
# 998   {'wavelength': [201.0, 202.0, 203.0, 204.0, 20...
# 999   {'wavelength': [201.0, 202.0, 203.0, 204.0, 20...
# 1000  {'wavelength': [201.0, 202.0, 203.0, 204.0, 20...
#
#                                               Cary_data
# 0     {'wavelength': [800.0, 799.833, 799.666, 799.4...
# 1     {'wavelength': [800.0, 799.833, 799.666, 799.4...
# 2     {'wavelength': [800.0, 799.833, 799.666, 799.4...
# 3     {'wavelength': [800.0, 799.833, 799.666, 799.4...
# 4     {'wavelength': [800.0, 799.833, 799.666, 799.4...
# ...                                                 ...
# 996   {'wavelength': [800, 799, 798, 797, 796, 795, ...
# 997   {'wavelength': [800, 799, 798, 797, 796, 795, ...
# 998   {'wavelength': [800, 799, 798, 797, 796, 795, ...
# 999   {'wavelength': [800, 799, 798, 797, 796, 795, ...
# 1000  {'wavelength': [800, 799, 798, 797, 796, 795, ...
#
# [1001 rows x 5 columns]

# %%
# if you choose to skip downloading all the raw .sb files, start here, uncomment the line and load in df assembled by authors using code above

#df = pd.read_pickle('cary_ultrapath_paired_measurements.pkl')# I have all the .sb files downloaded and made this .pkl using the cell above
#df

# %% [markdown]
# ### End section, assembling paired measurement table from individual files

# %% [markdown]
# ##### We now have the paired cary and ultrapath data organized in a dataframe, and can begin to conduct merges.
#
# We will save the merged products as new columns. See manuscript for in depth explanation
#
# Merged product dataframe identifiers:
# - val_th_0.4: value threshold merge values using the more conservative definition of $\mathrm{\lambda_{2}}$ where $\mathrm{a_{g, cary}}$ = 0.4 $\mathrm{m^{-1}}$
# - val_th_0.2: value threshold merge values using the less conservative definition of $\mathrm{\lambda_{2}}$ where $\mathrm{a_{g, cary}}$ = 0.2 $\mathrm{m^{-1}}$
# - pdiff: percent difference approach merge
#
# before next step, need to set up 2 functions:
# 1) function to compute value threshold merge
# 2) function to compute percent difference merge

# %%
def vth_merge(carydat, wgdat, threshold):

    # function to compute value threshold merge approach, customize lambda2 threshold
    # for cary + ultrapath ag data
    # carydat and wgdat are (601,) length numpy.ndarrays
    # returns merged output (601 len)
    # also returns wlmin and wlmax (use for histograms)
    #ex usage: 
    # merge, wvmin, wvmax = custom_vth_merge(carydat, wgdat, 0.4)

    # this edition of function allows you to input the right threshold
    # use for less conservative comparison

    # for this single sample, combing cary and ultrapath measurements to 1 df with uniform index
    u = pd.DataFrame(wgdat.copy())[['wavelength', 'ag']].set_index('wavelength').sort_index().rename(columns={"ag": "ultra_ag"})
    new_index = np.arange(int(u.index.min()), int(u.index.max()) + 1)
    u = u.reindex(new_index, method='nearest')

    c = pd.DataFrame(carydat.copy())[['wavelength', 'ag']].set_index('wavelength').sort_index().rename(columns={"ag": "cary_ag"})
    new_index = np.arange(int(c.index.min()), int(c.index.max()) + 1)
    c = c.reindex(new_index, method='nearest')

    u.index = u.index.astype('float')
    c.index = c.index.astype('float')
    ucdf = pd.concat([u,c], axis = 1)
    ucdf.sort_index(inplace=True)

    wg_max_idx = int(np.nanargmax(ucdf['ultra_ag']))# returns index of max wg ag datapoint
    ucdf.iloc[0:wg_max_idx, ucdf.columns.get_loc('ultra_ag')] = np.nan  # mask all data before max, remove positive slope region
    cary_max_idx = int(np.nanargmax(ucdf['cary_ag']))# returns index of max cary ag datapoint
    ucdf.iloc[0:cary_max_idx, ucdf.columns.get_loc('cary_ag')] = np.nan  # mask all data before max, remove some scan errors

    try:
        wvmin = int(np.where(ucdf['ultra_ag']>1.3818)[0][-1])# returns last index before waveguide ag goes below 1.3818
    except:
        wvmin = int(wg_max_idx)
        
    # if wvmin<49:
    #     wvmin=49# extra condition to ensure lower bound is below the range of the cary data

    wvmax = np.where(ucdf['cary_ag']<threshold)[0][0]# returns first index where cary ag < 0.4
    
    #print('wvmin, wvmax',wvmin, wvmax)
    #return ucdf
    x_interp=np.arange(wvmin, wvmax+1)
    #x_interp
    # next up, set up and execute interpolation
    y_interp=np.linspace(0,1,len(x_interp))# linear interp from 0 to 1
    
    merged_part1 = ucdf.iloc[:wvmin, ucdf.columns.get_loc('cary_ag')]#begining part of merged spectra is 100% cary
    merged_part3 = ucdf.iloc[wvmax+1:, ucdf.columns.get_loc('ultra_ag')]# end part of merged spectra is 100% WG
    
    # # Merged part2: 
    wg_mid = ucdf.iloc[wvmin:wvmax+1, ucdf.columns.get_loc('ultra_ag')]
    cary_mid= ucdf.iloc[wvmin:wvmax+1, ucdf.columns.get_loc('cary_ag')]


    merged_part2=wg_mid*y_interp + cary_mid*(1-y_interp)
    
    #print(len(merged_part1), len(merged_part2), len(merged_part3))
    # #complete the merge, 2 append statements to combine the 3 parts
    merged_parts1_2=np.append(merged_part1,merged_part2)
    merged_complete=np.append(merged_parts1_2, merged_part3)
    ucdf['vth_merge_'+str(threshold)]=merged_complete

    return ucdf, wvmin, wvmax

# %%
# set function to conduct percent difference merge

def pdiff_merge(carydat, wgdat):
    # funciton to conduct percent difference merge

    # clean up the data and organize
    u = pd.DataFrame(wgdat.copy())[['wavelength', 'ag']].set_index('wavelength').sort_index().rename(columns={"ag": "ultra_ag"})
    new_index = np.arange(int(u.index.min()), int(u.index.max()) + 1)
    u = u.reindex(new_index, method='nearest')

    c = pd.DataFrame(carydat.copy())[['wavelength', 'ag']].set_index('wavelength').sort_index().rename(columns={"ag": "cary_ag"})
    new_index = np.arange(int(c.index.min()), int(c.index.max()) + 1)
    c = c.reindex(new_index, method='nearest')

    u.index = u.index.astype('float')
    c.index = c.index.astype('float')
    ucdf = pd.concat([u,c], axis = 1)
    ucdf.sort_index(inplace=True)

    wg_max_idx = int(np.nanargmax(ucdf['ultra_ag']))# returns index of max wg ag datapoint
    ucdf.iloc[0:wg_max_idx, ucdf.columns.get_loc('ultra_ag')] = np.nan  # mask all data before max, remove positive slope region
    cary_max_idx = int(np.nanargmax(ucdf['cary_ag']))# returns index of max cary ag datapoint
    ucdf.iloc[0:cary_max_idx, ucdf.columns.get_loc('cary_ag')] = np.nan  # mask all data before max, remove some scan errors

    ucdf['pdiff'] = ((ucdf['cary_ag']-ucdf['ultra_ag'])/ucdf['ultra_ag'])
    
    wvmax=int(np.where(ucdf.index == 348)[0][0])
    try:
        wvmin = np.where(abs(ucdf.iloc[:wvmax, ucdf.columns.get_loc('pdiff')]-ucdf.iloc[wvmax, ucdf.columns.get_loc('pdiff')])>0.05)[0][-1]
    except:
        wvmin= 50 #index of 250nm

    x_interp=np.arange(wvmin, wvmax+1)
    # next up, set up and execute interpolation
    y_interp=np.linspace(0,1,len(x_interp))# linear interp from 0 to 1
    
    merged_part1 = ucdf.iloc[:wvmin, ucdf.columns.get_loc('cary_ag')]#begining part of merged spectra is 100% cary
    merged_part3 = ucdf.iloc[wvmax+1:, ucdf.columns.get_loc('ultra_ag')]# end part of merged spectra is 100% WG
    
    # # Merged part2: 
    wg_mid = ucdf.iloc[wvmin:wvmax+1, ucdf.columns.get_loc('ultra_ag')]
    cary_mid= ucdf.iloc[wvmin:wvmax+1, ucdf.columns.get_loc('cary_ag')]


    merged_part2=wg_mid*y_interp + cary_mid*(1-y_interp)
    
    #print(len(merged_part1), len(merged_part2), len(merged_part3))
    # #complete the merge, 2 append statements to combine the 3 parts
    merged_parts1_2=np.append(merged_part1,merged_part2)
    merged_complete=np.append(merged_parts1_2, merged_part3)
    ucdf['pdiff_merge']=merged_complete

    return ucdf, wvmin, wvmax

# %%
# this cell, iterate through rows, compute value threshold merge for 0.4 and 0.2 limit, and pdiff merge. add relevant parameters as new columns
val_th_list_04=[]
val_th_wlmin_list_04=[]
val_th_wlmax_list_04=[]

val_th_list_02=[]
val_th_wlmin_list_02=[]
val_th_wlmax_list_02=[]

pdiff_list =[]
pdiff_wlmin =[]
pdiff_wlmax =[]

for row in df.iterrows():
    
    #print(row[1]['cary_file'],len(row[1]['Cary_data']['wavelength'].copy()),len(row[1]['Ultrapath_data']['wavelength'].copy()))
    val_th_merged, wvmin, wvmax = vth_merge(row[1]['Cary_data'].copy(), row[1]['Ultrapath_data'].copy(), 0.4)
    # #print('completed ' + str(row[0])) 
    val_th_list_04.append(val_th_merged)
    val_th_wlmin_list_04.append(wvmin)
    val_th_wlmax_list_04.append(wvmax)
    #print(len(row[1]['Cary_data'].copy()), len(row[1]['Ultrapath_data'].copy()))

    #repeat for less conservative bounds
    val_th_merged, wvmin, wvmax = vth_merge(row[1]['Cary_data'].copy(), row[1]['Ultrapath_data'].copy(), 0.2)
    val_th_list_02.append(val_th_merged)
    val_th_wlmin_list_02.append(wvmin)
    val_th_wlmax_list_02.append(wvmax)

    pdiff_merged, wvmin, wvmax = pdiff_merge(row[1]['Cary_data'].copy(), row[1]['Ultrapath_data'].copy())
    pdiff_list.append(pdiff_merged)
    pdiff_wlmin.append(wvmin)
    pdiff_wlmax.append(wvmax)

df['val_th_merge_0.4']=val_th_list_04
df['val_th_wlmin_list_0.4']=val_th_wlmin_list_04
df['val_th_wlmax_list_0.4']=val_th_wlmax_list_04

df['val_th_merge_0.2']=val_th_list_02
df['val_th_wlmin_list_0.2']=val_th_wlmin_list_02
df['val_th_wlmax_list_0.2']=val_th_wlmax_list_02

df['pdiff_merge'] = pdiff_list
df['pdiff_wlmin'] = pdiff_wlmin
df['pdiff_wlmax'] = pdiff_wlmax
#df

# %%
# self-check plots
plt.hist(val_th_wlmin_list_02)
plt.figure()
plt.hist(val_th_wlmax_list_02)
# Out:
# (array([128.,  51.,  93., 294., 290., 127.,  14.,   2.,   0.,   2.]),
#  array([ 87. , 110.9, 134.8, 158.7, 182.6, 206.5, 230.4, 254.3, 278.2,
#         302.1, 326. ]),
#  <BarContainer object of 10 artists>)

# %%
# choose a row index in df, then plot the cary, ultrapath, and vth_merged data

row = df.iloc[830]
#interesting indecies
# 830 - ecoa
# 0 - nbs

plt.plot(row['val_th_merge_0.4'].index,row['val_th_merge_0.4']['ultra_ag'], label='ultrapath' )
plt.plot(row['val_th_merge_0.4'].index,row['val_th_merge_0.4']['cary_ag'], label='cary' )
#plt.plot(row['val_th_merge_0.4'].index,row['val_th_merge_0.4']['vth_merge_0.4'], label='merged 0.4' )
#plt.plot(row['val_th_merge_0.2'].index,row['val_th_merge_0.2']['vth_merge_0.2'], label='merged 0.2' )
plt.plot(row['pdiff_merge'].index,row['pdiff_merge']['pdiff_merge'], label='%diff merge')
plt.title(row['ultrapath_file'])
plt.legend()
#row['val_th_merge_0.4']

# %%
# summary plots: pdiff
fig, ax = plt.subplots(figsize=(6.5,5.2))
ax.set_xlabel('Wavelength (nm)', fontsize=17)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_ylim(-0.05,5.5)
ax.set_xlim(245, 730)
ax.set_title('percent difference merge full dataset')

for i in df['pdiff_merge'].values:
    ax.plot(i.index, i['pdiff_merge'], c='0.5', lw=0.06)

fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
#plt.savefig(odir+'all_merged.png', dpi=300, bbox_inches='tight')

# %%
# summary plots: vth_merge 0.4
fig, ax = plt.subplots(figsize=(6.5,5.2))
ax.set_xlabel('Wavelength (nm)', fontsize=17)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_ylim(-0.05,5.5)
ax.set_xlim(245, 730)
ax.set_title('Value Threshold 0.4 merge full dataset')

for i in df['val_th_merge_0.4'].values:
    ax.plot(i.index, i['vth_merge_0.4'], c='0.5', lw=0.06)

fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
#plt.savefig(odir+'all_merged.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Now, we have calculated all the merged cdom spectra for the analyses. Below, we conduct the analyses/produce the manuscript plots
#
# At this point, we have constructed a pandas dataframe df, which contains our original ultrapath and waveguide spectra, in addition to the computed value threshold merge (using thresholds of both 0.4 and 0.2), and the computed percent difference merge.

# %%
odir = 'publication_figures/'# set folder to write files to 
os.makedirs(odir, exist_ok=True)

# %%
# get lat and lon from seabass files:
lats = []
lons = []
for ultra_file in ultra_flist:
    ultra_sb = readSB(filename=ultra_dir+ultra_file, no_warn=True)
    lat = float(ultra_sb.headers['north_latitude'][:-5])
    lon = float(ultra_sb.headers['west_longitude'][:-5])
    if (lon < 60) & (lon>0):
        print(ultra_file)

    lats.append(lat)
    lons.append(lon)

# %%
# fig 1: data map
import cartopy
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.crs as ccrs

map_projection = cartopy.crs.Robinson()
cm = 1/2.54
fig, ax = plt.subplots(figsize=(18*cm,18*cm), nrows=1, subplot_kw={'projection': map_projection})
ax.set_global()
ax.add_feature(cartopy.feature.NaturalEarthFeature('physical', 'land', '50m'), facecolor='olive',)#edgecolor='k', linewidth=0.25)

gl = ax.gridlines( draw_labels=True, linewidth=0.5,
             color='0.7', alpha=1,linestyle='--')

gl.bottom_labels = False; gl.top_labels = True; gl.right_labels = False; gl.left_labels = True

ax.scatter(lons, lats, s=15, c='r', zorder=2, alpha=1,
           transform = cartopy.crs.PlateCarree(), edgecolor='k', linewidth=0.1)

oname = 'summary_map_ag_merge.png'
plt.tight_layout()
plt.savefig(odir+oname, dpi=300)#, bbox_inches='tight')
#add map to other map with powerpoint

# %%
# map insert zoom on east coast of US

map_projection = cartopy.crs.PlateCarree()
fig, ax = plt.subplots(figsize=(6*cm,6*cm), nrows=1, subplot_kw={'projection': map_projection})
ax.add_feature(cartopy.feature.NaturalEarthFeature('physical', 'land', '50m'), facecolor='olive',)#edgecolor='k', linewidth=0.25)
ax.add_feature(cartopy.feature.STATES, lw=0.2)
ext=[-77, -65, 34.5, 46]
ax.set_extent(ext, crs=map_projection)

ax.scatter(lons, lats, s=15, c='r', zorder=2, alpha=1,
           transform = cartopy.crs.PlateCarree(), edgecolor='k', linewidth=0.1)

oname = 'summary_map_ag_merge_subpanel.png'
fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
plt.tight_layout()
plt.savefig(odir+oname, dpi=300)#, bbox_inches='tight')

# %%
# Figure 1: Examples Cary vs ultrapath: Overall, plus zoom in on 
# UV and Red to show where each instrument is better
# since the UV is obvious to the naked eye, likely 
# won't use that zoomed-in subplot

#index 163, 167, 168 looks good for this

colors = ['#348ABD', '#E24A33', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colors)
x=168


#### full plot ####

fig, ax = plt.subplots(figsize=(6.5,5.2))
plt.plot(df.at[x, 'Cary_data']['wavelength'],df.at[x, 'Cary_data']['ag'], label='Cary 100' )
plt.plot(df.at[x, 'Ultrapath_data']['wavelength'],df.at[x, 'Ultrapath_data']['ag'], label='Ultrapath' )
ax.legend(fontsize=10, frameon=False)
ax.set_ylabel(r'$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)
ax.set_xlabel('Wavelength (nm)', fontsize=11)
ax.grid(lw=0.25)
ax.tick_params(axis='both', which='major', labelsize=15)
fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
plt.tight_layout()
#plt.savefig(odir+'fig_1_center.png', dpi=300)#, bbox_inches='tight')
# print(x)
# plt.show()

#### right edge zoom in ####

fig, ax = plt.subplots(figsize=(7*cm,6*cm))
plt.plot(df.at[x, 'Cary_data']['wavelength'],df.at[x, 'Cary_data']['ag'], lw=0.75, zorder=3 )
plt.plot(df.at[x, 'Ultrapath_data']['wavelength'],df.at[x, 'Ultrapath_data']['ag'], lw=0.75, zorder=3 )

#ax.set_ylabel('$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=13)
#ax.set_xlabel('Wavelength (nm)', fontsize=13)\
ax.tick_params(axis='both', which='major', labelsize=8)
ax.set_xlim(500, 800)
ax.set_ylim(-0.075, 0.075)
ax.grid(lw=0.25, zorder=0)

plt.axhline(0, c='k', linestyle='--', zorder=2, lw=1)
#fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
plt.tight_layout()
#plt.savefig(odir+'fig_1_right.png', dpi=300)#, bbox_inches='tight')
#plt.show()
#combine 2 plot pieces with ppt

# %%
# here, make plot showing fraction of merged product signal coming
# from each instrument source across wavelengths

fig, ax = plt.subplots(figsize=(8.5*cm,5*cm))
#fig, ax = plt.subplots(figsize=(18*cm,9*cm))
wvl = np.arange(250,726)

wmi=290; wma=368
x_interp=np.arange(wmi, wma+1)
y_interp=np.linspace(0,1,len(x_interp))

wg_fracs=np.append(np.append(np.zeros(wmi-250), y_interp), np.ones(725-wma))
cary_fracs=1-wg_fracs

ax.plot(wvl, cary_fracs, label='Cary 100')
ax.plot(wvl, wg_fracs, label='Ultrapath')
ax.legend(fontsize=10, frameon=False)


ax.set_xlabel('Wavelength (nm)',fontsize=11)
ax.set_ylabel('Fraction of \nMerged Signal',fontsize=11)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.grid(lw=0.25, zorder=0)
ax.axvline(wmi, c='0.5', zorder=0, lw=0.5, label=r'$\mathregular{a_g}$ Value Thresholds')
ax.axvline(wma-1, c='0.5', zorder=0, lw=0.5,)#, label='Cary ag < 0.4')
ax.annotate(r'$\mathrm{\lambda_{2}}$', [370, .21], fontsize=13)
ax.annotate(r'$\mathrm{\lambda_{1}}$', [243, .21], fontsize=13)

ax.set_xticks(ticks=[300,400,500,600,700])
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
ax.xaxis.set_minor_locator(AutoMinorLocator())
#ax.tick_params(which='both', width=2)
# ax.tick_params(which='major', length=7)
ax.tick_params(which='minor')



#plt.title('$\mathregular{a_g}$ Value Threshold Merge Approach Signal Fractions', fontsize=15)

#fig.patch.set_alpha(0.0)# to acheive transparent outer border, 

# this is a useful paramter to adjust for single column figures!
plt.subplots_adjust(left=0.24, right=0.97, top=0.96, bottom=0.23, wspace=0.14)
#plt.tight_layout()
plt.savefig(odir+'signal_fraction.png', dpi=300)#, bbox_inches='tight')

# %%
val_th_range = [a_i - b_i for a_i, b_i in zip(df['val_th_wlmax_list_0.4'].values, df['val_th_wlmin_list_0.4'].values)]
pdiff_range = [a_i - b_i for a_i, b_i in zip(df['pdiff_wlmax'].values, df['pdiff_wlmin'].values)]


fig, ax = plt.subplots(ncols=2, figsize=(18*cm,6*cm))
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[1].tick_params(axis='both', which='major', labelsize=10)

ax[0].hist(val_th_range, bins=18)
ax[1].hist(pdiff_range, bins=18)
ax[0].grid(lw=0.25, zorder=0)
ax[1].grid(lw=0.25, zorder=0)

ax[0].set_xlabel('Merge Range',fontsize=11)
ax[0].set_ylabel('Count',fontsize=11)
ax[1].set_xlabel('Merge Range',fontsize=11)

#fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
#plt.subplots_adjust(left=0.24, right=0.97, top=0.96, bottom=0.10, wspace=0.14)
plt.subplots_adjust(left=0.08, right=0.98, top=0.96, bottom=0.2, wspace=0.14)
#plt.savefig(odir+'histograms.png', dpi=300)#, bbox_inches='tight')

# %%
for r in df.iterrows():
    if ((r[1]['val_th_wlmax_list_0.4'] - r[1]['val_th_wlmin_list_0.4']) < 40):
        print(r[1]['ultrapath_file'])
# Out:
# CLiVEC_CV7_Ultrapath_waveguide_ag_20120811_st40_29.54m_R1.sb

# %%
# subdf = df.where(df['cruise']=='P16S').dropna(how='all')
# subdf

# %%
# summary plots: vth_merge 0.4
fig, ax = plt.subplots(figsize=(6.5,5.2))
ax.set_xlabel('Wavelength (nm)', fontsize=17)
ax.tick_params(axis='both', which='major', labelsize=15)
# ax.set_ylim(-0.05,5.5)
ax.set_xlim(245, 730)
ax.set_title('Value Threshold 0.4 merge full dataset')

for i in df['val_th_merge_0.4'].values:
    ax.plot(i.index, i['vth_merge_0.4'], c='0.5', lw=0.06)

fig.patch.set_alpha(0.0)# to acheive transparent outer border, 
#plt.savefig(odir+'all_merged.png', dpi=300, bbox_inches='tight')

# %%
# all percent difference plots, illustrate stable reigion
import matplotlib.patches as patches
fig, ax = plt.subplots(figsize=(8.5*cm,6*cm))

for r in df.iterrows():
    ax.plot(r[1]['pdiff_merge'].index, r[1]['pdiff_merge']['pdiff'], c='0.5', lw=0.04)

ax.set_ylim(-0.1,0.5)
ax.set_xlim(249, 400)
ax.set_xlabel('Wavelength (nm)',fontsize=11)
ax.set_ylabel('Percent Difference',fontsize=11)

ax.tick_params(axis='both', which='major', labelsize=10)
#ax.grid(lw=0.25, zorder=0)
ax.hlines(0,0,1000, colors='k', linestyle='--', lw=0.5)


# Add red box to highlight stable region
# Adjust these coordinates based on your stable region
stable_x_start = 300  # Start wavelength of stable region
stable_x_end = 346    # End wavelength of stable region
stable_y_start = 0.05 # Bottom y-coordinate of box
stable_y_end = 0.18   # Top y-coordinate of box
# Create rectangle
rect = patches.Rectangle((stable_x_start, stable_y_start), 
                        stable_x_end - stable_x_start,
                        stable_y_end - stable_y_start,
                        linewidth=0.5, 
                        edgecolor='red', 
                        facecolor='none',  # No fill color
                        zorder=10)

# Add rectangle to plot
ax.add_patch(rect)


plt.subplots_adjust(left=0.2, right=0.96, top=0.96, bottom=0.2, wspace=0.14)
plt.savefig(odir+'pdiffs.png', dpi=300)#, bbox_inches='tight')

# %%
# outdated code: abspectroscopy not reliable, use R package CDOM to do slope instead
# from numpy import inf as Inf
# # initialize function to compute cdom spectral slope
# def my_ag_slope(carydat,start_wl, end_wl, wl0):
#     # function to retrive cdom slope for a = a0*exp(-S*(x-wl0))+K
#     # x is wvl list
#     # y is ag value list
#     # start_wl and end_wl are the limits (integers) (e.g. S275:295 these are 275 and 295)
#     # wl0 is the reference wavelength

#     # first, make df
    
#     c = pd.DataFrame(carydat.copy())[['wavelength', 'ag']].set_index('wavelength').sort_index().rename(columns={"ag": "cary_ag"})
#     new_index = np.arange(int(c.index.min()), int(c.index.max()) + 1)
#     c = c.reindex(new_index, method='nearest')
#     c.index = c.index.astype('float')
#     df = c
#     df = df.reset_index()

#     #finally, crop to start_wl and end_wl
#     df=df.loc[(df['wavelength'] >= start_wl) & (df['wavelength'] <= end_wl)]



#     #return df
#     #print(df)
#     # next, calulate a0
#     a0 = df['cary_ag'].loc[df['wavelength']==wl0].values[0]
#     ia0=a0
#     #print('initial a0:', a0)
    
#     # good so far
#     y=df['cary_ag'].values
#     x=df['wavelength'].values
#     #print(x,y)

#     par_init_vals=[a0,0.02,0.01]# guesses for the initial values   # for [a0,S,K]
#     par_bounds= ([0, 0, -Inf], [max(y), 1, Inf])   

#     # scipy.optimize.curve_fit uses non-linear least squares to fit a 
#     # function, f, to data; bounds to constrain the optimization to the 
#     # region indicated by the lower and upper limit of the a0, S, K 
#     #parameters; maxfev specifies how many times the parameters for the 
#     #model that we are trying to fit are allowed to be altered
#     # adapted from: https://github.com/ClaCasc/AbspectroscoPY/blob/master/abs_fit_exponential.ipynb
    
#     popt,pcov=sp.optimize.curve_fit(lambda x,a0,S,K: a0*exp(-S*(x-wl0))+K,  x, y, p0 = par_init_vals, bounds = par_bounds, maxfev = 600)
#     #print('popt a0,S,K:',popt)                                   # the best-fit parameters.

#     a0=float(round(popt[0],4))                                           # round the parameter to three digits
#     S=float(round(popt[1],4))
#     K=float(round(popt[2],4)) 
#     #print('a0:',a0,'   S:', S, '   K:', K, '   wl0:', wl0, '   initial a0:',ia0 )
#     return a0,S,K

# %%
my_ag_slope(r[1]['Cary_data'],275, 295, 275)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 my_ag_slope(r[1]['Cary_data'],275, 295, 275)
#
# NameError: name 'my_ag_slope' is not defined

# %%
# make list of all cary cdom spectral slopes:
s_list=[]

for row in df.iterrows():

    a0,S,K=my_ag_slope(row[1]['Cary_data'],275, 295, 285)
    s_list.append(S)

# %% [markdown]
# ### Start Spectral slope seciton
# caveat - spectral slopes are calculated with R script (using code from R toolbox), results are saved to csv, and plotted with python here.
# If you want to replicate this you'll need to hop into R real quick and run the slope script, then come back. or use the csv of slopes determined
# by the authors + stored in this repository

# %%
# LOAD IN CDOM SLOPES CALCULATED IN R SCRIPT
# optional to skip this cell and the next one if you don't want to run R script

s_data = pd.read_csv('cary_s275_295.csv')


s_list = s_data['column_name'].values
s_list
# Out:
# array([0.0214944 , 0.0185722 , 0.02015833, ..., 0.03032463, 0.03005138,
#        0.02849931], shape=(1001,))

# %%
cm = 1/2.54  # centimeters in inches
fig, ax = plt.subplots( figsize=(8.5*cm,6*cm))
ax.tick_params(axis='both', which='major', labelsize=10)
ax.hist(s_list, bins=20)
ax.grid(lw=0.25, zorder=0)
ax.set_xlabel(r'CDOM Spectral Slope $S_{275:295}$ (nm$^{-1}$)', fontsize=11)
ax.set_ylabel('Count',fontsize=11)

hist_mean = np.mean(s_list)
hist_median = np.median(s_list)
hist_q1 = np.percentile(s_list, 25)
hist_q3 = np.percentile(s_list, 75)

stats_text = (
    #f'Mean: {hist_mean:.5f}\n'
    f'Median: {hist_median:.5f}\n'
    f'Q1: {hist_q1:.5f}\n'
    f'Q3: {hist_q3:.5f}'
)

xmax = plt.xlim()[1]
ymax = plt.ylim()[1]

ax.text(xmax * 0.95, ymax * 0.95, stats_text,
         ha='right', va='top', fontsize=10,
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

ax.set_xlim(0.013, xmax)

plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.2, wspace=0.14)
plt.savefig(odir+'slope_hist.png', dpi=300)#, bbox_inches='tight')

# %% [markdown]
# ### End spectral Slope section

# %%
# figure for merge results full dataset


cm = 1/2.54  # centimeters in inches
fig, ax = plt.subplots(nrows=2,  figsize=(8.5*cm,12*cm))

ax[0].set_ylim(-0.05,5.5)
ax[0].set_xlim(245, 730)
for i in df['val_th_merge_0.4'].values:
    ax[0].plot(i.index, i['vth_merge_0.4'], c='0.5', lw=0.03)


ax[1].set_ylim(-0.05,5.5)
ax[1].set_xlim(245, 730)

for i in df['pdiff_merge'].values:
    ax[1].plot(i.index, i['pdiff_merge'], c='0.5', lw=0.03)

ax[1].set_xlabel('Wavelength (nm)',fontsize=11)
ax[0].set_ylabel(r'$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)
ax[1].set_ylabel(r'$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)

# Inset plot for ax1
inset1 = inset_axes(ax[0], width="60%", height="60%", loc='upper right')
inset1.set_ylim(0,0.3)
inset1.set_xlim(300, 425)
for i in df['val_th_merge_0.4'].values:
    inset1.plot(i.index, i['vth_merge_0.4'], c='0.5', lw=0.03)
inset1.tick_params(labelsize=6)

# Inset plot for ax2
inset2 = inset_axes(ax[1], width="60%", height="60%", loc='upper right')
inset2.set_ylim(0,0.3)
inset2.set_xlim(300, 425)
for i in df['pdiff_merge'].values:
    inset2.plot(i.index, i['pdiff_merge'], c='0.5', lw=0.03)
inset2.tick_params(labelsize=6)


plt.subplots_adjust(left=0.14, right=0.98, top=0.98, bottom=0.1, wspace=0.14)
plt.savefig(odir+'merge_full_dataset.png', dpi=300)#, bbox_inches='tight')

# %%
df.keys()
# Out:
# Index(['ultrapath_file', 'cary_file', 'cruise', 'Ultrapath_data', 'Cary_data',
#        'val_th_merge_0.4', 'val_th_wlmin_list_0.4', 'val_th_wlmax_list_0.4',
#        'val_th_merge_0.2', 'val_th_wlmin_list_0.2', 'val_th_wlmax_list_0.2',
#        'pdiff_merge', 'pdiff_wlmin', 'pdiff_wlmax'],
#       dtype='object')

# %%
df.at[25, 'cruise']
# Out:
# 'P16S'

# %%
# next plot, 2 ag spectra and merges comparison, oligotrophic vs coastal

# big 2 panel plot to compare merges for a good and a bad spectrum

idx1=277
idx2=271

# 878 close

# PLot 1 good indexes to issustrate my point: 168, 287, 277, 276
# plot 2 good indexes to illustrate: 271, 357, 392, 388, 393, 394, 


cm = 1/2.54  # centimeters in inches
fig, ax = plt.subplots(nrows=2,  figsize=(18*cm,22*cm))


vtmin = float(df.at[idx1,'val_th_merge_0.4'].index[int(df.at[idx1, 'val_th_wlmin_list_0.4'].copy())])
vtmax = float(df.at[idx1,'val_th_merge_0.4'].index[int(df.at[idx1, 'val_th_wlmax_list_0.4'].copy())])
pdmin = float(df.at[idx1,'pdiff_merge'].index[int(df.at[idx1, 'pdiff_wlmin'].copy())])
pdmax = float(df.at[idx1,'pdiff_merge'].index[int(df.at[idx1, 'pdiff_wlmax'].copy())])

ax[0].axvline(int(vtmin), c='0.5', zorder=0, linestyle=':', lw=0.75)#, label=r'$\mathregular{a_g}$ Value Threshold'
ax[0].axvline(int(vtmax), c='0.5', zorder=0, linestyle=':', lw=0.75)#, label='Cary ag < 0.4')
ax[0].axvline(int(pdmin), c='0.5', zorder=0, linestyle=(0, (5, 5)), lw=0.75)#, label=r'$\mathregular{a_g}$ Percent Difference'
ax[0].axvline(int(pdmax), c='0.5', zorder=0, linestyle=(0, (5, 5)), lw=0.75)#, label='Cary ag < 0.4')

ax[0].plot(df.at[idx1, 'Cary_data']['wavelength'],df.at[idx1, 'Cary_data']['ag'], label=r'Cary 100 $\mathregular{a_g}$', lw=0.75)#
ax[0].plot(df.at[idx1, 'Ultrapath_data']['wavelength'],df.at[idx1, 'Ultrapath_data']['ag'], label=r'Ultrapath $\mathregular{a_g}$', lw=0.75 )#
ax[0].plot(df.at[idx1, 'val_th_merge_0.4']['vth_merge_0.4'], label=r'Value Threshold Merged $\mathregular{a_g}$', linestyle=':', c='k', lw=0.75)
ax[0].plot(df.at[idx1, 'pdiff_merge']['pdiff_merge'], label=r'Percent Difference Merged $\mathregular{a_g}$', linestyle=(0, (5, 5)), c='k', lw=0.75)



ax[0].set_ylabel(r'$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)
ax[0].set_xlabel('Wavelength (nm)', fontsize=11)
ax[0].set_xlim(272, 360)
ax[0].set_ylim(0.2, 1.9)
ax[0].tick_params(axis='both', which='major', labelsize=10)

annot = ('Merge Wavelengths:' + 
         '\nValue Threshold: ['+str(vtmin)+', '+str(vtmax)+']'+
         '\nPercent Difference: ['+str(pdmin)+', '+str(pdmax)+']')

ax[0].annotate(annot,
                xy=(0.99, 0.3),
                horizontalalignment='right',
                verticalalignment='bottom',
                fontsize=10,
                xycoords='axes fraction')

ax[0].legend(fontsize=10, loc='upper right')#, frameon=False)



# bottom panel
vtmin = float(df.at[idx2,'val_th_merge_0.4'].index[int(df.at[idx2, 'val_th_wlmin_list_0.4'].copy())])
vtmax = float(df.at[idx2,'val_th_merge_0.4'].index[int(df.at[idx2, 'val_th_wlmax_list_0.4'].copy())])
pdmin = float(df.at[idx2,'pdiff_merge'].index[int(df.at[idx2, 'pdiff_wlmin'].copy())])
pdmax = float(df.at[idx2,'pdiff_merge'].index[int(df.at[idx2, 'pdiff_wlmax'].copy())])

ax[1].axvline(int(vtmin), c='0.5', zorder=0, label=r'$\mathregular{a_g}$ Value Threshold', linestyle=':', lw=0.75)
ax[1].axvline(int(vtmax), c='0.5', zorder=0, linestyle=':', lw=0.75)#, label='Cary ag < 0.4')
ax[1].axvline(int(pdmin), c='0.5', zorder=0, linestyle=(0, (5, 5)), label=r'$\mathregular{a_g}$ Percent Difference', lw=0.75)
ax[1].axvline(int(pdmax), c='0.5', zorder=0, linestyle=(0, (5, 5)), lw=0.75)#, label='Cary ag < 0.4')

ax[1].plot(df.at[idx2, 'Cary_data']['wavelength'],df.at[idx2, 'Cary_data']['ag'], label=r'Cary 100 $\mathregular{a_g}$', lw=0.75)
ax[1].plot(df.at[idx2, 'Ultrapath_data']['wavelength'],df.at[idx2, 'Ultrapath_data']['ag'], label=r'Ultrapath $\mathregular{a_g}$', lw=0.75 )
ax[1].plot(df.at[idx2, 'val_th_merge_0.4']['vth_merge_0.4'], label=r'Value Threshold Merged $\mathregular{a_g}$', linestyle=':', c='k', lw=0.75)
ax[1].plot(df.at[idx2, 'pdiff_merge']['pdiff_merge'], label=r'Percent Difference Merged $\mathregular{a_g}$', linestyle=(0, (5, 5)), c='k', lw=0.75)



ax[1].set_ylabel(r'$\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)
ax[1].set_xlabel('Wavelength (nm)', fontsize=11)
ax[1].set_xlim(260, 390)
ax[1].set_ylim(0.05, 1.8)
ax[1].tick_params(axis='both', which='major', labelsize=10)
annot = ('Merge Wavelengths:' + 
         '\nValue Threshold: ['+str(vtmin)+', '+str(vtmax)+']'+
         '\nPercent Difference: ['+str(pdmin)+', '+str(pdmax)+']')

ax[1].annotate(annot,
                xy=(0.99, 0.3),
                horizontalalignment='right',
                verticalalignment='bottom',
                fontsize=10,
                xycoords='axes fraction')
plt.subplots_adjust(left=0.09, right=0.98, top=.99, bottom=0.05, wspace=0, hspace=0.06)
plt.savefig(odir+'2_merge_compare_examples.png', dpi=300)#, bbox_inches='tight')

# %% [markdown]
# #### Final section of plots: Derivitives

# %%
# Function to make spline, first, second derivitive

def get_splines(x,y):
    # determine spline interp, first, and second deriv of x,y
    # 1. first, logic to drop nan's
    mask = ~np.isnan(y)
    x = x[mask]# Apply the mask to both x and y
    y = y[mask]
    
    # 2. Perform cubic spline interpolation
    spline = CubicSpline(x, y)
    
    # 3. Compute the derivative of the spline (first derivative)
    spline_derivative_1 = spline.derivative()  # First derivative
    
    # 4. Compute the second derivative of the spline
    spline_derivative_2 = spline_derivative_1.derivative()  # Second derivative
    
    # 5. Define a fine grid of x values for plotting
    x_fine = np.linspace(min(x), max(x), 500)
    
    # 6. Evaluate the spline, its first derivative, and its second derivative on the fine grid
    y_spline = spline(x_fine)
    y_derivative_1 = spline_derivative_1(x_fine)
    y_derivative_2 = spline_derivative_2(x_fine)

    return y_spline, y_derivative_1, y_derivative_2, x_fine

# %%
idx2=277

cm = 1/2.54  # centimeters in inches
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(18*cm,13*cm))#max 18x22

vthdat=df.at[idx2, 'val_th_merge_0.4']['vth_merge_0.4'].copy()
wl = df.at[idx2, 'val_th_merge_0.4'].index
wl1_4=df.at[idx2,'val_th_wlmin_list_0.4'].copy()
wl2_4=df.at[idx2,'val_th_wlmax_list_0.4'].copy()

y0, y1, y2, xf = get_splines(wl,vthdat)

ax[0,0].plot(xf, y0, lw=0.75)
ax[1,0].plot(xf, y1, lw=0.75)
ax[2,0].plot(xf, y2, lw=0.75)

vthdat=df.at[idx2, 'val_th_merge_0.2']['vth_merge_0.2']
wl = df.at[idx2, 'val_th_merge_0.2'].index
wl1_2=df.at[idx2,'val_th_wlmin_list_0.2'].copy()
wl2_2=df.at[idx2,'val_th_wlmax_list_0.2'].copy()


y0, y1, y2, xf = get_splines(wl,vthdat)

ax[0,1].plot(xf, y0, lw=0.75)
ax[1,1].plot(xf, y1, lw=0.75)
ax[2,1].plot(xf, y2, lw=0.75)

ax[0,0].xaxis.set_tick_params(labelbottom=False)
ax[0,1].xaxis.set_tick_params(labelbottom=False)
ax[1,0].xaxis.set_tick_params(labelbottom=False)
ax[1,1].xaxis.set_tick_params(labelbottom=False)

ax[1,1].yaxis.set_tick_params(labelleft=False)
ax[2,1].yaxis.set_tick_params(labelleft=False)
ax[0,1].yaxis.set_tick_params(labelleft=False)

ax[2,0].set_xlabel('Wavelength (nm)', fontsize=11)
ax[2,1].set_xlabel('Wavelength (nm)', fontsize=11)

ax[0,0].set_ylabel(r'Spline $\mathregular{a_g}$ ($\mathregular{m^{-1}}$)', fontsize=11)
ax[1,0].set_ylabel('Spline dy/dx', fontsize=11)
ax[2,0].set_ylabel('Spline d²y/dx²', fontsize=11)

# left plots, vlines
ax[0,0].axvline(wvl[wl1_4],c='0.5',lw=0.5); ax[0,0].axvline(wvl[wl2_4],c='0.5',lw=0.5)
ax[1,0].axvline(wvl[wl1_4],c='0.5',lw=0.5); ax[1,0].axvline(wvl[wl2_4],c='0.5',lw=0.5)
ax[2,0].axvline(wvl[wl1_4],c='0.5',lw=0.5); ax[2,0].axvline(wvl[wl2_4],c='0.5',lw=0.5)
#right plots, vlines
ax[0,1].axvline(wvl[wl1_2],c='0.5',lw=0.5); ax[0,1].axvline(wvl[wl2_2],c='0.5',lw=0.5)
ax[1,1].axvline(wvl[wl1_2],c='0.5',lw=0.5); ax[1,1].axvline(wvl[wl2_2],c='0.5',lw=0.5)
ax[2,1].axvline(wvl[wl1_2],c='0.5',lw=0.5); ax[2,1].axvline(wvl[wl2_2],c='0.5',lw=0.5)

fig.align_ylabels(ax[:, 0])

plt.tight_layout()
plt.subplots_adjust(left=0.115, right=.995, top=.99, bottom=0.086)

plt.savefig(odir+'splines.png', dpi=300)#, bbox_inches='tight')

# %%
# full dataset spline average, comparing 0.2 vs 0.4 threshold merges

# now, magnitude of 2nd deriv plot for full dataset

# new plot:
# For full dataset, use spline analysis to compute magnitude of 
# second derivitive under both limit conditions. 

# create 2 lists to store calculated 2nd deriv magnitudes
# iterate through df rows
# determine+save 2nd deriv magnitude for more conservative approach
# calculate vth merge for less conservative
# determine+save 2nd deriv magnitude for less conservative approach
# take average for both
# plot both, pretty plot


second_deriv_list_0_4=[]
second_deriv_list_0_2=[]


for i in df['val_th_merge_0.4'].values:
    x = i.index
    y = i['vth_merge_0.4']
    # 1. first, logic to drop nan's
    mask = ~np.isnan(y)
    # print('mask',len(mask))
    # print('x', len(x))
    # print('y', len(y))
    x = x[mask]# Apply the mask to both x and y
    y = y[mask]
    # 2. Perform cubic spline interpolation
    spline = CubicSpline(x, y)
    # 3. Compute the derivative of the spline (first derivative)
    spline_derivative_1 = spline.derivative()  # First derivative
    # 4. Compute the second derivative of the spline
    spline_derivative_2 = spline_derivative_1.derivative()

    # 5. Define a fine grid of x values for plotting
    x_fine = np.linspace(min(x), max(x), 500)
    
    # 6. Evaluate the spline, its first derivative, and its second derivative on the fine grid
    y_spline = spline(x_fine)
    y_derivative_1 = spline_derivative_1(x_fine)
    y_derivative_2 = spline_derivative_2(x_fine)
    #print(len(y_spline))#all are the same, makes my life easier
    #print(type(y_derivative_2))
    #plt.plot(x_fine, y_spline)
    second_deriv_list_0_4.append(list(y_derivative_2))

for i in df['val_th_merge_0.2'].values:
    x = i.index
    y = i['vth_merge_0.2']

    #Now, within the same loop, repeat the analysis for the less conservatiive merge:

    # 1. first, logic to drop nan's
    mask = ~np.isnan(y)
    # print('mask',len(mask))
    # print('x', len(x))
    # print('y', len(y))
    x = x[mask]# Apply the mask to both x and y
    y = y[mask]
    # 2. Perform cubic spline interpolation
    spline = CubicSpline(x, y)
    # 3. Compute the derivative of the spline (first derivative)
    spline_derivative_1 = spline.derivative()  # First derivative
    # 4. Compute the second derivative of the spline
    spline_derivative_2 = spline_derivative_1.derivative()

    # 5. Define a fine grid of x values for plotting
    x_fine = np.linspace(min(x), max(x), 500)
    
    # 6. Evaluate the spline, its first derivative, and its second derivative on the fine grid
    y_spline = spline(x_fine)
    y_derivative_1 = spline_derivative_1(x_fine)
    y_derivative_2 = spline_derivative_2(x_fine)
    #print(len(y_spline))#all are the same, makes my life easier
    #print(type(y_derivative_2))
    #plt.plot(x_fine, y_spline)
    second_deriv_list_0_2.append(list(y_derivative_2))

# %%
# calculate averages of 2nd derivs
a = np.array(second_deriv_list_0_4)
b=np.mean(a, axis=0)

a2 = np.array(second_deriv_list_0_2)
b2=np.mean(a2, axis=0)

b3 = abs(b2) -abs(b)
neg=0
pos=0
for i in b3:
    if i>0:
        pos=pos+1
    elif i<0:
        neg=neg+1
print(pos, neg)
# Out:
# 199 105

# %%
cm = 1/2.54  # centimeters in inches
fig, ax = plt.subplots(nrows=2,  figsize=(8.5*cm,10*cm))

ax[0].plot(x_fine, abs(b), label=r'$\mathrm{\lambda_{2}}$ = $\mathrm{0.4 (m)^{-1}}$', lw=0.75)
ax[0].plot(x_fine, abs(b2), label=r'$\mathrm{\lambda_{2}}$ = $\mathrm{0.2 (m)^{-1}}$', lw=0.75)
ax[0].set_xlim(250, 425)
#ax[0].set_xlabel('Wavelength')
ax[0].set_ylabel('Mean |d²y/dx²|')
#plt.ylim(0, 0.002)
ax[0].legend(fontsize=10, frameon=False, loc='upper right')

ax[1].plot(x_fine, b3, label=r'($\mathrm{\lambda_{2}}$ = $\mathrm{0.2 (m)^{-1}}$) - ($\mathrm{\lambda_{2}}$ = $\mathrm{0.4 (m)^{-1}}$)', lw=0.75)
ax[1].set_xlim(250, 425)
ax[1].set_ylim(-0.0001, 0.002)
ax[1].set_xlabel('Wavelength')
ax[1].set_ylabel('|d²y/dx²| Difference')
ax[1].axhline(0, c='k', linestyle='--', lw=0.75)
#ax[1].legend()


ax[0].xaxis.set_tick_params(labelbottom=False)

fig.align_ylabels(ax[:])
plt.tight_layout()

plt.subplots_adjust(left=0.25, right=0.995, top=0.995, bottom=0.115)
plt.savefig(odir+'2nd_deriv_mag', dpi=300)

# %%
# plot to check cary data in red vs instrument noise threshold
# prints cruise when a sample is above instrument noise threshoild in red

abs_650_700_mag = []
k=0
for r in df.iterrows():
    #print(k)
    # k=k+1
    dat = r[1]['Cary_data']
    #print(dat.keys())
    wavelengths = np.array(dat['wavelength'])
    try:
        abs_values = np.array(dat['abs_ag'])
    except:
        abs_values = np.array(dat['abs'])

    lambda1, lambda2 = 650, 700
    mask = (wavelengths >= lambda1) & (wavelengths <= lambda2)
    filtered_abs = abs_values[mask]

    # Get the value with greatest magnitude (absolute value)
    max_magnitude_value = filtered_abs[np.argmax(np.abs(filtered_abs))]
    abs_650_700_mag.append(np.abs(max_magnitude_value))
    if np.abs(max_magnitude_value)>0.001:
        print(r[1]['cruise'])
        k=k+1
print(k)
# Out:
# P16S_2014
# P16S_2014
# P16S_2014
# P16S_2014
# CV3
# CV3
# CV5
# CV6
# CV6
# CV6
# CV6
# CV6
# CV6
# CV6
# CV6
# CV6
# CV6
# ECOA-3
# ECOA-3
# KR_2016
# KR_2016
# KR_2016
# KR_2016
# KR_2016
# KR_2016
# 25

# %%
# histogram for instrument noise in red. vast majority of samples occur below 0.001, no null needed
max_value = np.max(abs_650_700_mag)
bin_width = 0.00025
num_bins = int(np.ceil(max_value / bin_width))

# Create bin edges starting at 0
bin_edges = np.arange(0, (num_bins + 1) * bin_width, bin_width)

counts, bin_edges, patches = plt.hist(abs_650_700_mag, bins=bin_edges, edgecolor='black', alpha=0.7)

# Add count labels on top of each bin
for i, count in enumerate(counts):
    if count > 0:  # Only label bins that have data
        # Calculate the center of each bin for x-position
        bin_center = (bin_edges[i] + bin_edges[i+1]) / 2
        # Place text slightly above the bar
        plt.text(bin_center, count + max(counts)*0.01, str(int(count)), 
                ha='center', va='bottom', fontsize=9)

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Greatest Absorbance Signal Magnitude between 650-700nm')
plt.show()
